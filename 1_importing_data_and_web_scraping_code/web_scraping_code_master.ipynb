# %% [markdown]
# # Importing files from the web
# # Make HTTP requests (Get requests)
# # Scrape web data such as HTML
# # Parse HTML (using Beautiful Soup)
# # Pull data from APIs

# %% [markdown]
# # Importing flat files from the web

# %%
# Importing files manually is not scalable and not reproducible
# Instead you can use Urllib and Request packages

# %%
# urlopen() is similiar to open() but accepts URLs as inputs
# A Unform / Universal Resource Locators (URL) is simply a reference to web resources
# Most URLs are web addresses but can also be database access or FTP
# Web addresses are made up of the Protocol, e.g. HTTP, and the resource name, e.g. google.com
# HTTP stands for HyperText Transfer Protocol
# Every time you visit a website you send a HTTP request to a web server known as a GET request
# urlretrieve() performs a GET request and saves the relevant data locally

# %%
from urllib.request import urlretrieve

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# %%
urlretrieve(url, 'winequality-white.csv')
# Out:
# ('winequality-white.csv', <http.client.HTTPMessage at 0x10490f780>)

# %%
# Import package
from urllib.request import urlretrieve

# Import pandas
import pandas as pd

# Assign url of file: url
url = 'https://s3.amazonaws.com/assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

# The flat file contains tabular data of physiochemical properties of red wine, such as pH, alcohol content and citric acid content, along with wine quality rating.
# Save file locally
urlretrieve(url, 'winequality-red.csv')

# Read file into a DataFrame and print its head
df = pd.read_csv('winequality-red.csv', sep=';')
print(df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # You can also use Pandas read_csv to load the data directly without first saving locally

# %%
# Import packages
import matplotlib.pyplot as plt
import pandas as pd

# Assign url of file: url
url = 'https://s3.amazonaws.com/assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

# Read file into a DataFrame: df
df = pd.read_csv(url, sep = ';')

# Print the head of the DataFrame
print(df.head())

# Plot first column of df
pd.DataFrame.hist(df.ix[:, 0:1])
plt.xlabel('fixed acidity (g(tartaric acid)/dm$^3$)')
plt.ylabel('count')
plt.show()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # You can also import other files types such as Excel files

# %%
# Import package
import pandas as pd

# Assign url of file: url
url = 'http://s3.amazonaws.com/assets.datacamp.com/course/importing_data_into_r/latitude.xls'

# Read in all sheets of Excel file: xl
xl = pd.read_excel(url, sheetname = None)

# Print the sheetnames to the shell
print(xl.keys())

# Print the head of the first sheet (using its name, NOT its index)
print(xl['1700'].head())
# Out:
# dict_keys(['1700', '1900'])
#                  country       1700
# 0            Afghanistan  34.565000
# 1  Akrotiri and Dhekelia  34.616667
# 2                Albania  41.312000
# 3                Algeria  36.720000
# 4         American Samoa -14.307000

# %% [markdown]
# # HTTP requests to import files from the web

# %%
# HTML stands for HyperText Markup Language and is the standard markup language for the web

# %%
from urllib.request import urlopen, Request

# %%
url = 'https://www.wikipedia.org/'

# %%
request = Request(url)

# %%
response = urlopen(request)

# %%
html = response.read()

# %%
response.close()

# %%
# Another example!
# Import packages
from urllib.request import urlopen, Request

# Specify the url
url = "http://www.datacamp.com/teach/documentation"

# This packages the request: request
request = Request(url)

# Sends the request and catches the response: response
response = urlopen(request)

# Print the datatype of response
print(type(response))

# Be polite and close the response!
response.close()

# %% [markdown]
# # Using requests

# %%
import requests

# %%
url = 'https://www.wikipedia.org/'

# %%
r = requests.get(url)

# %%
text = r.text

# %%
print(text)
# Out:
# <!DOCTYPE html>
# <html lang="mul" class="no-js">
# <head>
# <meta charset="utf-8">
# <title>Wikipedia</title>
# <meta name="description" content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation.">
# <![if gt IE 7]>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <![endif]>
# <!--[if lt IE 7]><meta http-equiv="imagetoolbar" content="no"><![endif]-->
# <meta name="viewport" content="initial-scale=1,user-scalable=yes">
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico">
# <link rel="license" href="//creativecommons.org/licenses/by-sa/3.0/">
# <style>
# ...

# %%
# Another example
# Import package
import requests

# Specify the url: url
url = "http://docs.datacamp.com/teach/"

# Packages the request, send the request and catch the response: r
r = requests.get(url)

# Extract the response: text
text = r.text

# Print the html
print(text)
# Out:
# <!DOCTYPE html>
# <link rel="shortcut icon" href="images/favicon.ico" />
# <html>
#
#   <head>
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#
#   <title>Home</title>
#   <meta name="description" content="All Documentation on Course Creation">
#
#   <link rel="stylesheet" href="/teach/css/main.css">
#   <link rel="canonical" href="/teach/">
#   <link rel="alternate" type="application/rss+xml" title="DataCamp Teach Documentation" href="/teach/feed.xml" />
# </head>
#
#
#   <body>
#
#     <header class="site-header">
#
#   <div class="wrapper">
#
#     <a class="site-title" href="/teach/">DataCamp Teach Documentation</a>
#
#   </div>
#
# </header>
#
#
#     <div class="page-content">
#       <div class="wrapper">
#         <p>The Teach Documentation has been moved to <a href="https://www.datacamp.com/teach/documentation">https://www.datacamp.com/teach/documentation</a>!</p>
# ...

# %% [markdown]
# # Scraping the web in Python using Beautiful Soup

# %%
# HTML is a mix of structured and unstructured data
# Structured data is either organised in a pre-defined manner OR has a pre-defined data model
# Unstructured data has niether a pre-defined data model NOR has it been organised in a pre-defined manner

# %%
# Beautiful Soup is a Python package for extracting data from HTML
# In web development, the term Tag Soup refers to syntactically incorrect web code written for a web page

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = 'https://www.crummy.com/software/BeautifulSoup/'

# %%
r = requests.get(url)

# %%
html_doc = r.text

# %%
soup = BeautifulSoup(html_doc)
# Out:
# /Users/nigelnicholson/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Users/nigelnicholson/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/transitional.dtd">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Beautiful Soup: We called him Tortoise because he taught us.
#   </title>
#   <link href="mailto:leonardr@segfault.org" rev="made"/>
#   <link href="/nb/themes/Default/nb.css" rel="stylesheet" type="text/css"/>
#   <meta content="Beautiful Soup: a library designed for screen-scraping HTML and XML." name="Description"/>
#   <meta content="Markov Approximation 1.4 (module: leonardr)" name="generator"/>
#   <meta content="Leonard Richardson" name="author"/>
#  </head>
#  <body alink="red" bgcolor="white" link="blue" text="black" vlink="660066">
#   <img align="right" src="10.1.jpg" width="250"/>
#   <br/>
#   <p>
#    You didn't write that awful page. You're just trying to get some
# data out of it. Beautiful Soup is here to help. Since 2004, it's been
# ...

# %%
print(soup.title)
# Out:
# <title>Beautiful Soup: We called him Tortoise because he taught us.</title>

# %%
print(soup.get_text())
# Out:
# Beautiful Soup: We called him Tortoise because he taught us.
#
#
#
#
#
#
#
#
# You didn't write that awful page. You're just trying to get some
# data out of it. Beautiful Soup is here to help. Since 2004, it's been
# saving programmers hours or days of work on quick-turnaround
# screen scraping projects.
#
# Beautiful Soup
# "A tremendous boon." -- Python411 Podcast
# [ Download | Documentation | Hall of Fame | Source | Discussion group ]
# If Beautiful Soup has saved you a lot of time and money, the
# best way to pay me back is to check out Constellation
# Games, my sci-fi novel about alien video games.You can
# read
# the first two chapters for free, and the full novel starts at 5
# USD. Thanks!
# If you have questions, send them to the discussion
# group. If you find a bug, file it.
# Beautiful Soup is a Python library designed for quick turnaround
# projects like screen-scraping. Three features make it powerful:
#
#
# ...

# %%
# Another example
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url = 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup = soup.prettify()

# Print the response
print(pretty_soup)
# Out:
# <html>
#  <head>
#   <title>
#    Guido's Personal Home Page
#   </title>
#  </head>
#  <body bgcolor="#FFFFFF" text="#000000">
#   <h1>
#    <a href="pics.html">
#     <img border="0" src="images/IMG_2192.jpg"/>
#    </a>
#    Guido van Rossum - Personal Home Page
#   </h1>
#   <p>
#    <a href="http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm">
#     <i>
#      "Gawky and proud of it."
#     </i>
#    </a>
#   </p>
#   <h3>
#    <a href="http://metalab.unc.edu/Dave/Dr-Fun/df200004/df20000406.jpg">
#     Who
# I Am
#    </a>
#   </h3>
#   <p>
#    Read
# my
#    <a href="http://neopythonic.blogspot.com/2016/04/kings-day-speech.html">
#     "King's
# Day Speech"
#    </a>
#    for some inspiration.
#   </p>
#   <p>
#    I am the author of the
#    <a href="http://www.python.org">
#     Python
#    </a>
#    programming language.  See also my
#    <a href="Resume.html">
#     resume
#    </a>
#    and my
#    <a href="Publications.html">
# ...

# %% [markdown]
# # Turning a webpage into data using BeautifulSoup: getting the text

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url = 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extract the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Get the title of Guido's webpage: guido_title
guido_title = soup.title

# Print the title of Guido's webpage to the shell
print(guido_title)

# Get Guido's text: guido_text
guido_text = soup.get_text()

# Print Guido's text to the shell
print(guido_text)
# Out:
# <title>Guido's Personal Home Page</title>
#
#
# Guido's Personal Home Page
#
#
#
#
# Guido van Rossum - Personal Home Page
# "Gawky and proud of it."
# Who
# I Am
# Read
# my "King's
# Day Speech" for some inspiration.
#
# I am the author of the Python
# programming language.  See also my resume
# and my publications list, a brief bio, assorted writings, presentations and interviews (all about Python), some
# pictures of me,
# my new blog, and
# my old
# blog on Artima.com.  I am
# @gvanrossum on Twitter.  I
# also have
# a G+
# profile.
#
# In January 2013 I joined
# Dropbox.  I work on various Dropbox
# products and have 50% for my Python work, no strings attached.
# Previously, I have worked for Google, Elemental Security, Zope
# Corporation, BeOpen.com, CNRI, CWI, and SARA.  (See
# my resume.)  I created Python while at CWI.
#
# How to Reach Me
# You can send email for me to guido (at) python.org.
# I read everything sent there, but if you ask
# ...

# %% [markdown]
# # Turning a webpage into data using BeautifulSoup: getting the hyperlinks

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url
url = 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Print the title of Guido's webpage
print(soup.title)

# Find all 'a' tags (which define hyperlinks): a_tags
a_tags = soup.find_all('a')

# Print the URLs to the shell
for link in a_tags:
    print(link.get('href'))
# Out:
# <title>Guido's Personal Home Page</title>
# pics.html
# http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm
# http://metalab.unc.edu/Dave/Dr-Fun/df200004/df20000406.jpg
# http://neopythonic.blogspot.com/2016/04/kings-day-speech.html
# http://www.python.org
# Resume.html
# Publications.html
# bio.html
# http://legacy.python.org/doc/essays/
# http://legacy.python.org/doc/essays/ppt/
# interviews.html
# pics.html
# http://neopythonic.blogspot.com
# http://www.artima.com/weblogs/index.jsp?blogger=12088
# https://twitter.com/gvanrossum
# https://plus.google.com/u/0/115212051037621986145/posts
# http://www.dropbox.com
# Resume.html
# http://groups.google.com/groups?q=comp.lang.python
# http://stackoverflow.com
# guido.au
# http://legacy.python.org/doc/essays/
# images/license.jpg
# http://www.cnpbagwell.com/audio-faq
# http://sox.sourceforge.net/
# images/internetdog.gif
# ...

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url
url = 'https://www.dunnhumby.com'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Print the title of Guido's webpage
print(soup.title)

# Find all 'a' tags (which define hyperlinks): a_tags
a_tags = soup.find_all('a')

# Print the URLs to the shell
for link in a_tags:
    print(link.get('href'))
# Out:
# <title>dunnhumby – We're a customer science company</title>
# #
# https://www.dunnhumby.com//
# /client-login
# /
# /about-us
# /solutions
# /resources
# /clients
# /careers
# /contact
# https://gnc-us.dunnhumby.com
# https://tesco-ie.dunnhumby.com/dh.shop
# https://macys-us.dunnhumby.com/dh.MyServices/Authentication/Login.aspx
# https://metro-ca.dunnhumby.com/dh.MyServices/Authentication/Login.aspx?ReturnUrl=/dh.MyServices/default.aspx
# https://pam-it.dunnhumby.com/dh.MyServices/Authentication/Login.aspx?ReturnUrl=/dh.MyServices/default.aspx
# https://raleys-us.dunnhumby.com/dh.MyServices/Authentication/Login.aspx
# https://gb.clientportal.dunnhumby.com/tuk
# https://lms.kallidus.com/dunnhumby/external
# https://lms.kallidus.com/dunnhumby/
# http://www.tescoacademy.com/
# None
# http://info.dunnhumby.com/NRFBigShow2017
# /influencermediaplanning
# /retailer-research2016
# /trends-and-insights
# ...

# %%
# Pull JSON data from APIs
# An API is a set of protocols and routines for building and interacting with software applications

# %%
# The standard form for pulling data is JSON files
# This stands for JavaScript Object Notation
# When loading JSON files into Python it makes sense to store them in a dictionary: dict
# The JSON file format arose out of a growing need for real-time server-to-browser communication

# %% [markdown]
# # Using the OMDb movie API

# %%
import requests
# HTTP signal we are making a HTTP request and the www.omdbapi.com that we are querying this API
# The /? is called the query string. How to use is covered in the documentation on the OMDb website
url = 'http://www.omdbapi.com/?t=Snakes on a plane'
# Package and send the request and catch the response in one line of code:
r = requests.get(url)
json_data = r.json()
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Runtime:  105 min
# Year:  2006
# Awards:  3 wins & 7 nominations.
# Rated:  R
# Country:  Germany, USA, Canada
# imdbRating:  5.6
# Genre:  Action, Adventure, Crime
# Director:  David R. Ellis
# Type:  movie
# imdbVotes:  117,183
# Language:  English
# Title:  Snakes on a Plane
# Writer:  John Heffernan (screenplay), Sebastian Gutierrez (screenplay), David Dalessandro (story), John Heffernan (story)
# Metascore:  58
# Actors:  Samuel L. Jackson, Julianna Margulies, Nathan Phillips, Rachel Blanchard
# Response:  True
# imdbID:  tt0417148
# Released:  18 Aug 2006
# Poster:  https://images-na.ssl-images-amazon.com/images/M/MV5BZDY3ODM2YTgtYTU5NC00MTE4LTkzNjktMzNhZWZmMzJjMWRjXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg
# Plot:  An FBI agent takes on a plane full of deadly and venomous snakes, deliberately released to kill a witness being flown from Honolulu to Los Angeles to testify against a mob boss.

# %%
# Import requests package
import requests

# Assign URL to variable: url
url = 'http://www.omdbapi.com/?t=social+network'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Print the text of the response
print(r.text)
# Out:
# {"Title":"The Social Network","Year":"2010","Rated":"PG-13","Released":"01 Oct 2010","Runtime":"120 min","Genre":"Biography, Drama","Director":"David Fincher","Writer":"Aaron Sorkin (screenplay), Ben Mezrich (book)","Actors":"Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons","Plot":"Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, but is later sued by two brothers who claimed he stole their idea, and the co-founder who was later squeezed out of the business.","Language":"English, French","Country":"USA","Awards":"Won 3 Oscars. Another 161 wins & 162 nominations.","Poster":"https://images-na.ssl-images-amazon.com/images/M/MV5BMTM2ODk0NDAwMF5BMl5BanBnXkFtZTcwNTM1MDc2Mw@@._V1_SX300.jpg","Metascore":"95","imdbRating":"7.7","imdbVotes":"491,784","imdbID":"tt1285016","Type":"movie","Response":"True"}

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'http://www.omdbapi.com/?t=social+network'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Runtime:  120 min
# Year:  2010
# Awards:  Won 3 Oscars. Another 161 wins & 162 nominations.
# Rated:  PG-13
# Country:  USA
# imdbRating:  7.7
# Genre:  Biography, Drama
# Director:  David Fincher
# Type:  movie
# imdbVotes:  491,784
# Language:  English, French
# Title:  The Social Network
# Writer:  Aaron Sorkin (screenplay), Ben Mezrich (book)
# Metascore:  95
# Actors:  Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons
# Response:  True
# imdbID:  tt1285016
# Released:  01 Oct 2010
# Poster:  https://images-na.ssl-images-amazon.com/images/M/MV5BMTM2ODk0NDAwMF5BMl5BanBnXkFtZTcwNTM1MDc2Mw@@._V1_SX300.jpg
# Plot:  Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, but is later sued by two brothers who claimed he stole their idea, and the co-founder who was later squeezed out of the business.

# %% [markdown]
# # Checking out the Wikipedia API

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=pizza'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# The query will return nested JSONs, that is, JSONs with JSONs, but Python can handle that because it will translate them into dictionaries within dictionaries
# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# Print the Wikipedia page extract
pizza_extract = json_data['query']['pages']['24768']['extract']
print(pizza_extract)
# Out:
# <p><b>Pizza</b> is a yeasted flatbread generally topped with tomato sauce and cheese and baked in an oven. It is commonly topped with a selection of meats, vegetables and condiments. The term was first recorded in the 10th century, in a Latin manuscript from Gaeta in Central Italy. The modern pizza was invented in Naples, Italy, and the dish and its variants have since become popular and common in many areas of the world.</p>
# <p>In 2009, upon Italy's request, Neapolitan pizza was safeguarded in the European Union as a Traditional Speciality Guaranteed dish. The Associazione Verace Pizza Napoletana (the True Neapolitan Pizza Association) is a non-profit organization founded in 1984 with headquarters in Naples. It promotes and protects the "true Neapolitan pizza".</p>
# ...

# %% [markdown]
# # Using the Twitter API with API authentication and OAuth

# %%
# How to stream data from the twitter API
# How to filter incoming tweets for keywords
# How to use the Tweetpy Python package

# %%
# Twitter has a number of APIs
# The REST API allows programmatic access to read and write Twitter data
# If you want to monitor or process tweets in real time then use the Streaming API instead

# %%
# The Streaming API has a number of different options: 
# https://dev.twitter.com/streaming/reference/get/statuses/sample - returns small random sample
# https://dev.twitter.com/streaming/reference/get/statuses/firehose - not publicly available
# Tweets are returned as JSON files
# See the field guide for more info on interpretation: https://dev.twitter.com/overview/api/tweets

# %%
# API key: JZRQjMfUnZNE6DiF5aRU3DcjM
# Consumer secret (API secret): IekGWcEodNupZyY25l3740T7w4lhJ2Zc9kFVWFFmPrwMmXPZTj
# Owner ID: 208890502
'''
Your application's publicly accessible home page, where users can go to download, make use of, or find out more information about your application. 
This fully-qualified URL is used in the source attribution for tweets created by your application and will be shown in user-facing authorization screens.
(If you don't have a URL yet, just put a placeholder here but remember to change it later.)
'''

# %%
# The package tweepy is great at handling all the Twitter API OAuth Authentication details for you
# All you need to do is to pass your authentication credentials to it. 
import tweepy, json

# %%
import config
# Out:
#   File "/Users/nigelnicholson/anaconda/lib/python3.5/site-packages/config.py", line 733
#     except Exception, e:
#                     ^
# SyntaxError: invalid syntax

# %%
# Import package
import tweepy

# Store OAuth authentication credentials in relevant variables
access_token = "208890502-KYfiOy6m8a8c30J07xQxN7n1zZRZL83vMCGiZ9sR"
access_token_secret = "8a0YXysrDj56v6gTbnqRiJebygKazJod6XMgjPixq7sVC"
consumer_key = "JZRQjMfUnZNE6DiF5aRU3DcjM"
consumer_token_secret = "IekGWcEodNupZyY25l3740T7w4lhJ2Zc9kFVWFFmPrwMmXPZTj"

# Pass OAuth details to tweepy's OAuth handler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Sets the access token of the authentication object
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

class TwitterListener(StreamListener):
    def on_status(self, status):
        print(status.text)
    
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False

twitter_stream = Stream(auth, TwitterListener())
twitter_stream.filter(track=['python'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-7ec6d17c98d0> in <module>()
#      12
#      13 twitter_stream = Stream(auth, TwitterListener())
# ---> 14 twitter_stream.filter(track=['python'])
#
# /Users/nigelnicholson/anaconda/lib/python3.5/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /Users/nigelnicholson/anaconda/lib/python3.5/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# ...

# %%
import json

with open("data/stream_lunch.json") as infile:
    line = infile.readline()
    tweet = json.loads(line)
    print(json.dumps(tweet, indent=4))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-a43139792e12> in <module>()
#       1 import json
#       2
# ----> 3 with open("data/stream_lunch.json") as infile:
#       4     line = infile.readline()
#       5     tweet = json.loads(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/stream_lunch.json'

# %%
# "keep the connection open" and gather all upcoming tweets about a particular topic, event or person
# Now that authentication credentials have been set up, it is possible to stream some tweets! 
# Define the class Stream Listener
class MyStreamListener(tweepy.StreamListener):
    def __init__(self, api=None):
        super(MyStreamListener, self).__init__()
        self.num_tweets = 0
        self.file = open("tweets.txt", "w")
        
    def on_status(self, status):
        tweet = status._json
        self.file.write(json.dumps(tweet) + '\n')
        tweet_list.append(status)
        self.num_tweets += 1
        if self.num_tweets < 10000:
            return True 
        else:
            return False
        self.file.close()

# Initialize Stream listener
l = MyStreamListener()

# %%
# Create you Stream object with authentication
stream = tweepy.Stream(auth, l)

# Filter Twitter Streams to capture data by the keywords:
stream.filter(track = ['apple','microsoft'])

# Now that you've got your Twitter data sitting locally in a text file, it's time to explore it
# Import package
import json

# String of path to file: tweets_data_path
tweets_data_path = 'tweets.txt'

# Initialize empty list to store tweets: tweets_data
tweets_data = []

# Open connection to file
tweets_file = open(tweets_data_path, "r")

# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet = json.loads(line)
    tweets_data.append(tweet)

# Close connection to file
tweets_file.close()

# Now that you have the Twitter data in a list of dictionaries tweets_data
# Where each dictionary corresponds to a single tweet 
# Extract the text of the tweets, along with the language of the tweet
# The text in a tweet t1 is stored as the value t1['text']
# Similarly, the language is stored in t1['lang']
# Build a DataFrame in which each row is a tweet and has two columns, one for text, the other for lang
# Import package
import pandas as pd

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(tweets_data, columns=['text','lang'])

# Print head of DataFrame
print(df.head())
# Out:
# Empty DataFrame
# Columns: [text, lang]
# Index: []

# %%
# Now that you have your DataFrame of tweets set up
# Count how many tweets contain the words 'clinton', 'trump', 'sanders' and 'cruz'
import re

def word_in_text(word, tweet):
    word = word.lower()
    text = tweet.lower()
    match = re.search(word, tweet)

    if match:
        return True
    return False

# Iterate over the rows of the DataFrame
# Calculate how many tweets contain each of our keywords
# Initialize list to store tweet counts
[clinton, trump, sanders, cruz] = [0, 0, 0, 0]

# Iterate through df, counting the number of tweets in which
# each candidate is mentioned
for index, row in df.iterrows():
    clinton += word_in_text('clinton', row['text'])
    trump += word_in_text('trump', row['text'])
    sanders += word_in_text('sanders', row['text'])
    cruz += word_in_text('cruz', row['text'])
    
# Import packages
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn style
sns.set(color_codes=True)

# Create a list of labels:cd
cd = ['clinton', 'trump', 'sanders', 'cruz']

# Plot histogram
ax = sns.barplot(cd, [clinton, trump, sanders, cruz])
ax.set(ylabel="count")
plt.show()

# %%
from TwitterAPI import TwitterAPI
access_token_key = "208890502-KYfiOy6m8a8c30J07xQxN7n1zZRZL83vMCGiZ9sR"
access_token_secret = "8a0YXysrDj56v6gTbnqRiJebygKazJod6XMgjPixq7sVC"
consumer_key = "JZRQjMfUnZNE6DiF5aRU3DcjM"
consumer_secret = "IekGWcEodNupZyY25l3740T7w4lhJ2Zc9kFVWFFmPrwMmXPZTj"
api = TwitterAPI(consumer_key, consumer_secret, access_token_key, access_token_secret)
r = api.request('search/tweets', {'q':'pizza'})
for item in r:
        print(item)
# Out:
# {'extended_entities': {'media': [{'media_url': 'http://pbs.twimg.com/media/C2BsFiGUkAA8yX_.jpg', 'source_user_id': 834316544, 'id': 819773974489894912, 'url': 'https://t.co/xMl3RXdoTd', 'media_url_https': 'https://pbs.twimg.com/media/C2BsFiGUkAA8yX_.jpg', 'source_status_id': 819773978453512194, 'expanded_url': 'https://twitter.com/ItsFoodPorn/status/819773978453512194/photo/1', 'source_status_id_str': '819773978453512194', 'id_str': '819773974489894912', 'type': 'photo', 'indices': [36, 59], 'sizes': {'small': {'h': 582, 'resize': 'fit', 'w': 600}, 'medium': {'h': 582, 'resize': 'fit', 'w': 600}, 'large': {'h': 582, 'resize': 'fit', 'w': 600}, 'thumb': {'h': 150, 'resize': 'crop', 'w': 150}}, 'source_user_id_str': '834316544', 'display_url': 'pic.twitter.com/xMl3RXdoTd'}, {'media_url': 'http://pbs.twimg.com/media/C2BsFigUoAAMx37.jpg', 'source_user_id': 834316544, 'id': 819773974598950912, 'url': 'https://t.co/xMl3RXdoTd', 'media_url_https': 'https://pbs.twimg.com/media/C2BsFigUoAAMx3
# ...
